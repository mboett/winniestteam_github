# %%
import os
import string

fName = 'dblp_purified.xml'

if os.path.exists(fName):
    os.remove(fName)
else:
    print("Non c'è")

open(fName, 'x')
nf = open(fName, 'a')
f = open('/home/alessandro/Documents/WebApp/winniestteam-wa1819/src/main/database/dblp.xml')
#for l in range(892698):
#    f.readline()


for line in f:
    nf.write(line.replace('&', '800A'))

f.close()
nf.close()

print("FUCK YEAH!")
# Out:
# Non c'è
# FUCK YEAH!

# %%
f = open('dblp.xml')

for i in range(10000000):
    temp = f.readline()
    if temp.lower().find("clef")>-1:
        print(temp)

f.close()
# Out:
# <title>Invertible Weak Entwining Structures and Weak <i>C</i>-cleft Extensions.</title>
#
# <title>Cleft Extensions of Hopf Algebroids.</title>
#
# <title>Corrigendum to Cleft Extensions of Hopf Algebroids.</title>
#
# <title>Impossible Differential Attacks on 13-Round CLEFIA-128.</title>
#
# <title>An analysis of evaluation campaigns in ad-hoc medical information retrieval: CLEF eHealth 2013 and 2014.</title>
#
# <title>Dictionary-Based Cross-Language Information Retrieval: Learning Experiences from CLEF 2000-2002.</title>
#
# <title>European research letter: Cross-language system evaluation: The CLEF campaigns.</title>
#
# <title>Analysis of Biomedical and Health Queries: Lessons Learned from TREC and CLEF Evaluation Benchmarks.</title>
#
# <title>Determination of clefts in receptor structures.</title>
#
# <title>Functionality map analysis of the active site cleft of human thrombin.</title>
#
# ...

# %%
f = open('dblp.xml')

for i in range(10000000):
    if i==7002171:
        print(f.readline())
    else:
        f.readline()

f.close()
# Out:
# <title>Low Probability Differentials and the Cryptanalysis of Full-Round CLEFIA-128.</title>
